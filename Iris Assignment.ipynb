# %% [markdown]
# # Iris Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.Read the dataset to python environment

# %%
Iris_data=pd.read_csv('Iris.csv')

# %%
Iris_data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 2. Display the columns in the dataset

# %%
Iris_data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
Iris_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ## 3. Calculate the mean of each column of the dataset.

# %%
Iris_data[['SL','SW','PL','PW']].mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ## Check for the null values present in the dataset.

# %%
Iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# We could see there are total 150 entries and each column has 150 non-null entries. Which means there is no null values in any of the column.

# %% [markdown]
# ## 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
Iris_data[['SW','SL','PL','PW']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure(figsize=(6,15))

plt.subplot(4,1,1)
plt.scatter(Iris_data['Classification'],Iris_data['SL'],s=12, c='red',marker='^')
plt.title('Plot of Classification VS SL',fontsize=16)
plt.xlabel('Classification')
plt.ylabel('SL')

plt.subplot(4,1,2)
plt.scatter(Iris_data['Classification'],Iris_data['SW'],s=12, c='Blue',marker='^')
plt.title('Plot of Classification VS SW',fontsize=16)
plt.xlabel('Classification')
plt.ylabel('SW')

plt.subplot(4,1,3)
plt.scatter(Iris_data['Classification'],Iris_data['PL'],s=12, c='Green',marker='^')
plt.title('Plot of Classification VS PL',fontsize=16)
plt.xlabel('Classification')
plt.ylabel('PL')

plt.subplot(4,1,4)
plt.scatter(Iris_data['Classification'],Iris_data['PW'],s=12, c='Violet',marker='^')
plt.title('Plot of Classification VS PW',fontsize=16)
plt.xlabel('Classification')
plt.ylabel('PW')

plt.tight_layout()

# %%
sns.pairplot(Iris_data)
